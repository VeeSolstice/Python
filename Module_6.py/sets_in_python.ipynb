# %%
# Sets are non- sequential collection of items
#  comma seperated elements enclosed within {}

# %%
set1 = {10, "Python, 2.5"}
print(set1)
print(type(set1))
# Out:
# {10, 'Python, 2.5'}
# <class 'set'>

# %%
# Cannot have indexing with sets. Slicing also not allowed.
print(set[0])
# Out:
# set[0]

# %%
# Length of the set
print(len(set1))
# Out:
# 2

# %%
# Key feature: Sets do not allow duplicate elements 
l1 = [10, 2.5, 10, 30, 10]
print(l1, type(l1))
s1 = {10, 2.5, 10, 30, 10}
print(s1, type(s1))
# Out:
# [10, 2.5, 10, 30, 10] <class 'list'>
# {10, 2.5, 30} <class 'set'>
