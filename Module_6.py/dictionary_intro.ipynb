# %%
# dictionary is 
# comma seperated
# key-value pairs
# enclosed within {}
# {key1:value1, key2:value2,......}

groceries = {'milk':60, 'biscuits': 20, 'rice':90, 'bread':30}
print(groceries, type(groceries))
# Out:
# {'milk': 60, 'biscuits': 20, 'rice': 90, 'bread': 30} <class 'dict'>

# %%
# Length = No. of Key:Value pairs
print(len(groceries))
# Out:
# 4

# %%
# No indexing in dictionaries

# %%
# fetching values
print(groceries['milk'])
# Out:
# 60

# %%
# Dictionaries are mutable
groceries['milk'] = 65
print(groceries)
# Out:
# {'milk': 65, 'biscuits': 20, 'rice': 90, 'bread': 30}

# %%
# addition of new key-value pairs
groceries['eggs'] = 10
groceries['bread'] = 35 # updates the value of the key
print(groceries)
# Out:
# {'milk': 65, 'biscuits': 20, 'rice': 90, 'bread': 35, 'eggs': 10}
