# %%
for num in range(10):
    if num % 3 == 0: # if the number is divisible by 3
        continue
      
    print(num)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8

# %%
for num in range(10):
    if num % 3 == 0: # if the number is divisible by 3
        break
    
    print(num)
