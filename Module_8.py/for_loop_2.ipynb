# %%
s1 = "Hello World"

for char in s1:
    print(char)
print("End of the loop")
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d
# End of the loop

# %%
employee = {'empid': 1001, 'name': "John Gray", "department": "HR"}

for i in employee:
    print(i, employee[i])
# Out:
# empid 1001
# name John Gray
# department HR

# %%
employee = {'empid': 1001, 'name': "John Gray", "department": "HR"}

print(employee.items())

for i in employee.items():
    print(i[0], i[1])
# Out:
# dict_items([('empid', 1001), ('name', 'John Gray'), ('department', 'HR')])
# empid 1001
# name John Gray
# department HR
